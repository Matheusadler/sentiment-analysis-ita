# %%
from polyglot.text import Text

# %%
text = Text('o avanço na corrida espacial é algo muito importante para a história')

# %%
if text.polarity > 0:
    sentiment.append(1)
elif text.polarity < 0:
    sentiment.append(-1)
else:
    sentiment.append(0)

sentiment
# Out:
# [1]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mathe\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
dataset = pd.read_csv('g1_clean.csv', engine='python')

# %%
dataset['Keyword'] = [str(x).replace("'", "").replace(";", "").replace('"', "") for x in dataset['Keyword'].values]

# %%
dataset.head()
# Out:
#    Unnamed: 0                Author            Published  \
# 0           0      'Paulo Fernandes  2016-05-06T14:14:23
# 1           1            'Mirage Tf  2016-05-06T16:54:39
# 2           2        'Rodrigo Braga  2016-05-06T13:43:52
# 3           3            'Tucanofdp  2016-05-06T14:12:40
# 4           4  'Wellington Oliveira  2016-05-06T11:05:33
#
#                                              Comment  Likes  Dislikes  \
# 0       kg de equipamentos e armadura kg de bateria.     17         1
# 1  vÃ£o fazer igual o outro, funciona com luz sol...      4         0
# 2  kkkkkk posso ir? levo meu super nintendo, prometo     20         1
# 3  VocÃª serÃ¡ bem vindo Rodrigo,nÃ³s sobrevivent...     15         0
# 4  Os ETs que visitam a terra nada mais sÃ£o que ...     39        11
#
#                                          Article Keyword
# 0  Nasa apresenta robÃ´ humanoide \'astronauta\'    NASA
# 1  Nasa apresenta robÃ´ humanoide \'astronauta\'    NASA
# 2  Nasa apresenta robÃ´ humanoide \'astronauta\'    NASA
# 3  Nasa apresenta robÃ´ humanoide \'astronauta\'    NASA
# 4  Nasa apresenta robÃ´ humanoide \'astronauta\'    NASA

# %%
for row in dataset['Comment'].values:
    text = Text(row)
    if text.polarity > 0:
        sentiment.append(1)
    elif text.polarity < 0:
        sentiment.append(-1)
    else:
        sentiment.append(0)
